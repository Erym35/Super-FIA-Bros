# %% [markdown]
# # Super Mario Bros NEAT AI - Colab Runner
#
# This notebook allows you to train and run the AI on Google Colab using `gym-super-mario-bros`.

# %% [markdown]
# ## 0. Setup Google Drive
# Mount your Google Drive to access the project files. Make sure you have uploaded the **entire project folder** to your Drive.

# %%
from google.colab import drive
import os

# Mount Drive
drive.mount('/content/drive')

# CHANGE THIS PATH to where you uploaded the folder on your Drive
# Example: /content/drive/MyDrive/SuperMarioBros-AI/super-mario-neat
project_path = '/content/drive/MyDrive/super-mario-neat'

try:
    os.chdir(project_path)
    print(f"Successfully changed directory to {os.getcwd()}")
except FileNotFoundError:
    print(f"Error: The path '{project_path}' does not exist. Please check your Google Drive structure.")
# Out:
# Mounted at /content/drive
# Successfully changed directory to /content/drive/MyDrive/super-mario-neat

# %% [markdown]
# ## 1. Install Dependencies
# We need to install the NES emulator wrapper and NEAT.

# %%
# !apt-get update > /dev/null 2>&1
# !apt-get install -y python-opengl ffmpeg > /dev/null 2>&1
# !pip install gym-super-mario-bros nes-py neat-python opencv-python

# %% [markdown]
# ## 2. Verify Config
# Ensure the configuration file is present and correct.

# %%
import os
if not os.path.exists('src/config'):
    print("Error: Config file not found! Make sure you refer to the correct folder.")
else:
    print("Config file found.")
# Out:
# Config file found.

# %% [markdown]
# ## 3. Train the AI
# Run the training script for a few generations to test.

# %%
# !python src/main.py train --gen 10 --parallel 2
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# loaded checkpoint...
#
#  ****** Running generation 0 ******
#
# Process Process-1:
# Process Process-2:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 4. Run the Best Model
# Run the best genome found (or the default `finisher.pkl`).

# %%
# !python src/main.py run --file src/finisher.pkl --config src/config
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/super-mario-neat/src/main.py", line 35, in <module>
#     r.main(args.config, args.file, args.level)
#   File "/content/drive/MyDrive/super-mario-neat/src/run.py", line 25, in main
#     env = gym_super_mario_bros.make('SuperMarioBros-'+level+'-v0')
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gym/envs/registration.py", line 662, in make
#     env = env_creator(**_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^
# ...
