# %%
import os
import gym
import numpy as np
import cv2
from gym.spaces import Box
from nes_py.wrappers import JoypadSpace
import gym_super_mario_bros
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
from stable_baselines3.common.callbacks import CheckpointCallback, BaseCallback
from stable_baselines3.common.utils import set_random_seed

# 1. CARTELLE E PERCORSI
CHECKPOINT_DIR = './train/ttlivelli'
LOG_DIR = './logs/'
LOAD_MODEL_PATH = r"C:\Users\matte\Desktop\marioia\mario_stabile\train\PP02\mario_model_VITTORIA.zip"

os.makedirs(CHECKPOINT_DIR, exist_ok=True)
os.makedirs(LOG_DIR, exist_ok=True)

# --- CALLBACK PERSONALIZZATO PER SALVARE ALLA BANDIERA ---
class SaveOnFlagCallback(BaseCallback):
    def __init__(self, check_freq, save_path, verbose=1):
        super(SaveOnFlagCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _on_step(self) -> bool:
        # Recuperiamo i dati 'info' dall'ambiente
        # self.locals['infos'] contiene i dati di ogni ambiente vettorializzato
        for info in self.locals['infos']:
            if info.get('flag_get'):
                print(f"\n--- !!! BANDIERA RAGGIUNTA !!! ---")
                print(f"Salvataggio modello speciale in corso...")
                save_file = os.path.join(self.save_path, "mario_model_VITTORIA")
                self.model.save(save_file)
                print(f"Modello salvato come: {save_file}.zip")
        return True

# --- CLASSE AMBIENTE ---
class MarioModernized(gym.Env):
    def __init__(self):
        super().__init__()
        inner_env = gym_super_mario_bros.make('SuperMarioBros-v0')
        self.mario = JoypadSpace(inner_env, SIMPLE_MOVEMENT)
        self.observation_space = Box(low=0, high=255, shape=(84, 84, 1), dtype=np.uint8)
        self.action_space = self.mario.action_space
        
        self.max_x = 0
        self.stagnant_steps = 0
        self.skip_frames = 4 
        self.view_stack = [np.zeros((84, 84), dtype=np.uint8)] * 4

    def _process_frame(self, frame):
        if frame is not None:
            gray = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
            resized = cv2.resize(gray, (84, 84), interpolation=cv2.INTER_AREA)
            
            self.view_stack.pop(0)
            self.view_stack.append(resized)
            film_strip = np.hstack(self.view_stack)
            big_strip = cv2.resize(film_strip, (84*4*2, 84*2), interpolation=cv2.INTER_NEAREST)
            
            cv2.imshow("Memoria IA (4 Frame)", big_strip)
            cv2.waitKey(1)
            
            return resized[:, :, np.newaxis]
        return np.zeros((84, 84, 1), dtype=np.uint8)

    def reset(self, seed=None, options=None):
        self.max_x = 0
        self.stagnant_steps = 0
        self.view_stack = [np.zeros((84, 84), dtype=np.uint8)] * 4
        obs = self.mario.reset()
        self.mario.render()
        return self._process_frame(obs)

    def step(self, action):
        total_reward = 0
        for _ in range(self.skip_frames):
            obs, reward, done, info = self.mario.step(action)
            total_reward += reward
            if done: break

        self.mario.render()
        
        current_x = info['x_pos']
        if current_x > self.max_x:
            diff = current_x - self.max_x
            total_reward += diff 
            self.max_x = current_x
            self.stagnant_steps = 0
        else:
            self.stagnant_steps += 1

        if done and info['flag_get'] is False:
            total_reward -= 50 

        if info['flag_get']:
            total_reward += 500
            
        if self.stagnant_steps > 150: 
            total_reward -= 20
            done = True 

        obs = self._process_frame(obs)
        return obs, float(total_reward / 10.0), done, info

if __name__ == "__main__":
    SEED = 42
    set_random_seed(SEED)
    
    env = DummyVecEnv([lambda: MarioModernized()])
    env.seed(SEED)
    env = VecFrameStack(env, n_stack=4, channels_order='last')

    # 1. Callback standard per salvare ogni 100k passi
    checkpoint_callback = CheckpointCallback(
        save_freq=100000, 
        save_path=CHECKPOINT_DIR,
        name_prefix='mario_model'
    )

    # 2. Callback speciale per salvare quando Mario vince
    flag_callback = SaveOnFlagCallback(
        check_freq=1, 
        save_path=CHECKPOINT_DIR
    )

    # CARICAMENTO
    if os.path.exists(LOAD_MODEL_PATH):
        print(f"Caricamento modello da: {LOAD_MODEL_PATH}")
        model = PPO.load(LOAD_MODEL_PATH, env=env)
    else:
        print("ERRORE: Modello non trovato.")
        exit()

    print("Ripresa allenamento. Salvataggio automatico attivo e monitoraggio bandiera ON.")
    
    try:
        # Passiamo ENTRAMBI i callback in una lista
        model.learn(
            total_timesteps=1000000, 
            callback=[checkpoint_callback, flag_callback],
            reset_num_timesteps=False
        )
    except KeyboardInterrupt:
        print("Salvataggio modello finale...")
        model.save("mario_model_final_v2")
    finally:
        cv2.destroyAllWindows()
# Out:
# Caricamento modello da: C:\Users\matte\Desktop\marioia\mario_stabile\train\PP02\mario_model_VITTORIA.zip
# Wrapping the env in a VecTransposeImage.
# Ripresa allenamento. Salvataggio automatico attivo e monitoraggio bandiera ON.
# Logging to ./logs/PPO_8
# C:\Users\matte\Desktop\marioia\mario_stabile\Lib\site-packages\gym_super_mario_bros\smb_env.py:148: RuntimeWarning: overflow encountered in scalar subtract
#   return (self.ram[0x86] - self.ram[0x071c]) % 256
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# --------------------------------
# | time/              |         |
# |    fps             | 56      |
# |    iterations      | 1       |
# |    time_elapsed    | 36      |
# |    total_timesteps | 2443772 |
# --------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 56         |
# |    iterations           | 2          |
# |    time_elapsed         | 73         |
# |    total_timesteps      | 2445820    |
# | train/                  |            |
# |    approx_kl            | 0.08334087 |
# |    clip_fraction        | 0.252      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.535     |
# |    explained_variance   | 0.728      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 59         |
# |    n_updates            | 11910      |
# |    policy_gradient_loss | 0.0175     |
# |    value_loss           | 273        |
# ----------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 3           |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 2447868     |
# | train/                  |             |
# |    approx_kl            | 0.033693343 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.557      |
# |    explained_variance   | 0.896       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 54.7        |
# |    n_updates            | 11920       |
# |    policy_gradient_loss | 0.00326     |
# |    value_loss           | 153         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 53          |
# |    iterations           | 4           |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 2449916     |
# | train/                  |             |
# |    approx_kl            | 0.045371767 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.58       |
# |    explained_variance   | 0.896       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 52          |
# |    n_updates            | 11930       |
# |    policy_gradient_loss | 0.00048     |
# |    value_loss           | 118         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 53          |
# |    iterations           | 5           |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 2451964     |
# | train/                  |             |
# |    approx_kl            | 0.054314148 |
# |    clip_fraction        | 0.27        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.654      |
# |    explained_variance   | 0.894       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 39.1        |
# |    n_updates            | 11940       |
# |    policy_gradient_loss | 0.00812     |
# |    value_loss           | 102         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 53         |
# |    iterations           | 6          |
# |    time_elapsed         | 228        |
# |    total_timesteps      | 2454012    |
# | train/                  |            |
# |    approx_kl            | 0.03271477 |
# |    clip_fraction        | 0.207      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.604     |
# |    explained_variance   | 0.93       |
# |    learning_rate        | 0.0001     |
# |    loss                 | 32         |
# |    n_updates            | 11950      |
# |    policy_gradient_loss | -0.00496   |
# |    value_loss           | 85.3       |
# ----------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 53          |
# |    iterations           | 7           |
# |    time_elapsed         | 267         |
# |    total_timesteps      | 2456060     |
# | train/                  |             |
# |    approx_kl            | 0.036591545 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.641      |
# |    explained_variance   | 0.959       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 17.1        |
# |    n_updates            | 11960       |
# |    policy_gradient_loss | -0.00587    |
# |    value_loss           | 62.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 8           |
# |    time_elapsed         | 340         |
# |    total_timesteps      | 2458108     |
# | train/                  |             |
# |    approx_kl            | 0.030955529 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.706      |
# |    explained_variance   | 0.957       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 20          |
# |    n_updates            | 11970       |
# |    policy_gradient_loss | -0.00489    |
# |    value_loss           | 57.8        |
# -----------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 47         |
# |    iterations           | 9          |
# |    time_elapsed         | 391        |
# |    total_timesteps      | 2460156    |
# | train/                  |            |
# |    approx_kl            | 0.02624679 |
# |    clip_fraction        | 0.213      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.712     |
# |    explained_variance   | 0.948      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 23.3       |
# |    n_updates            | 11980      |
# |    policy_gradient_loss | -0.00164   |
# |    value_loss           | 120        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 44          |
# |    iterations           | 10          |
# |    time_elapsed         | 455         |
# |    total_timesteps      | 2462204     |
# | train/                  |             |
# |    approx_kl            | 0.051493924 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.6        |
# |    explained_variance   | 0.955       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 21.1        |
# |    n_updates            | 11990       |
# |    policy_gradient_loss | 0.00188     |
# |    value_loss           | 66.5        |
# -----------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 45          |
# |    iterations           | 11          |
# |    time_elapsed         | 494         |
# |    total_timesteps      | 2464252     |
# | train/                  |             |
# |    approx_kl            | 0.020838775 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.646      |
# |    explained_variance   | 0.96        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 31.1        |
# |    n_updates            | 12000       |
# |    policy_gradient_loss | -0.00417    |
# |    value_loss           | 79.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 45          |
# |    iterations           | 12          |
# |    time_elapsed         | 542         |
# |    total_timesteps      | 2466300     |
# | train/                  |             |
# |    approx_kl            | 0.038957976 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.579      |
# |    explained_variance   | 0.932       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 40          |
# |    n_updates            | 12010       |
# |    policy_gradient_loss | 0.00386     |
# |    value_loss           | 112         |
# -----------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 41          |
# |    iterations           | 13          |
# |    time_elapsed         | 635         |
# |    total_timesteps      | 2468348     |
# | train/                  |             |
# |    approx_kl            | 0.031823166 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.582      |
# |    explained_variance   | 0.947       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 39          |
# |    n_updates            | 12020       |
# |    policy_gradient_loss | -0.00474    |
# |    value_loss           | 84.8        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 14         |
# |    time_elapsed         | 731        |
# |    total_timesteps      | 2470396    |
# | train/                  |            |
# |    approx_kl            | 0.03649699 |
# |    clip_fraction        | 0.203      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.586     |
# |    explained_variance   | 0.948      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 21.8       |
# |    n_updates            | 12030      |
# |    policy_gradient_loss | -0.00831   |
# |    value_loss           | 87.4       |
# ----------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 15          |
# |    time_elapsed         | 823         |
# |    total_timesteps      | 2472444     |
# | train/                  |             |
# |    approx_kl            | 0.027478773 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.508      |
# |    explained_variance   | 0.928       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 60.7        |
# |    n_updates            | 12040       |
# |    policy_gradient_loss | -0.000814   |
# |    value_loss           | 165         |
# -----------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 16          |
# |    time_elapsed         | 925         |
# |    total_timesteps      | 2474492     |
# | train/                  |             |
# |    approx_kl            | 0.039031096 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.63       |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 40.8        |
# |    n_updates            | 12050       |
# |    policy_gradient_loss | 0.00159     |
# |    value_loss           | 126         |
# -----------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 17          |
# |    time_elapsed         | 1014        |
# |    total_timesteps      | 2476540     |
# | train/                  |             |
# |    approx_kl            | 0.030507147 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.632      |
# |    explained_variance   | 0.954       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 35.1        |
# |    n_updates            | 12060       |
# |    policy_gradient_loss | 0.00886     |
# |    value_loss           | 82.7        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 18         |
# |    time_elapsed         | 1111       |
# |    total_timesteps      | 2478588    |
# | train/                  |            |
# |    approx_kl            | 0.03466145 |
# |    clip_fraction        | 0.232      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.626     |
# |    explained_variance   | 0.956      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 23.6       |
# |    n_updates            | 12070      |
# |    policy_gradient_loss | 0.00271    |
# |    value_loss           | 82.9       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 19          |
# |    time_elapsed         | 1194        |
# |    total_timesteps      | 2480636     |
# | train/                  |             |
# |    approx_kl            | 0.052860968 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.661      |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 36.7        |
# |    n_updates            | 12080       |
# |    policy_gradient_loss | 0.00305     |
# |    value_loss           | 122         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 20          |
# |    time_elapsed         | 1271        |
# |    total_timesteps      | 2482684     |
# | train/                  |             |
# |    approx_kl            | 0.031899974 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.584      |
# |    explained_variance   | 0.945       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 31.5        |
# |    n_updates            | 12090       |
# |    policy_gradient_loss | 0.00431     |
# |    value_loss           | 110         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 21          |
# |    time_elapsed         | 1317        |
# |    total_timesteps      | 2484732     |
# | train/                  |             |
# |    approx_kl            | 0.051132657 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.607      |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 37.4        |
# |    n_updates            | 12100       |
# |    policy_gradient_loss | 0.00944     |
# |    value_loss           | 133         |
# -----------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 22          |
# |    time_elapsed         | 1393        |
# |    total_timesteps      | 2486780     |
# | train/                  |             |
# |    approx_kl            | 0.024654148 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.562      |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 50.1        |
# |    n_updates            | 12110       |
# |    policy_gradient_loss | -0.00988    |
# |    value_loss           | 105         |
# -----------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 32         |
# |    iterations           | 23         |
# |    time_elapsed         | 1458       |
# |    total_timesteps      | 2488828    |
# | train/                  |            |
# |    approx_kl            | 0.02695043 |
# |    clip_fraction        | 0.204      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.61      |
# |    explained_variance   | 0.93       |
# |    learning_rate        | 0.0001     |
# |    loss                 | 35.9       |
# |    n_updates            | 12120      |
# |    policy_gradient_loss | -0.00194   |
# |    value_loss           | 113        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 32         |
# |    iterations           | 24         |
# |    time_elapsed         | 1523       |
# |    total_timesteps      | 2490876    |
# | train/                  |            |
# |    approx_kl            | 0.03335898 |
# |    clip_fraction        | 0.207      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.72      |
# |    explained_variance   | 0.941      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 33.2       |
# |    n_updates            | 12130      |
# |    policy_gradient_loss | -0.00511   |
# |    value_loss           | 95.2       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 25          |
# |    time_elapsed         | 1579        |
# |    total_timesteps      | 2492924     |
# | train/                  |             |
# |    approx_kl            | 0.028809963 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.67       |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 56.2        |
# |    n_updates            | 12140       |
# |    policy_gradient_loss | -0.00214    |
# |    value_loss           | 149         |
# -----------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 26          |
# |    time_elapsed         | 1645        |
# |    total_timesteps      | 2494972     |
# | train/                  |             |
# |    approx_kl            | 0.020126957 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.636      |
# |    explained_variance   | 0.947       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 28.9        |
# |    n_updates            | 12150       |
# |    policy_gradient_loss | -0.00559    |
# |    value_loss           | 84          |
# -----------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 27          |
# |    time_elapsed         | 1717        |
# |    total_timesteps      | 2497020     |
# | train/                  |             |
# |    approx_kl            | 0.026049957 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.666      |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 22.3        |
# |    n_updates            | 12160       |
# |    policy_gradient_loss | -0.00922    |
# |    value_loss           | 60.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 28          |
# |    time_elapsed         | 1793        |
# |    total_timesteps      | 2499068     |
# | train/                  |             |
# |    approx_kl            | 0.025915544 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.571      |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 20          |
# |    n_updates            | 12170       |
# |    policy_gradient_loss | -0.0172     |
# |    value_loss           | 59.2        |
# -----------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 31        |
# |    iterations           | 29        |
# |    time_elapsed         | 1856      |
# |    total_timesteps      | 2501116   |
# | train/                  |           |
# |    approx_kl            | 0.0212106 |
# |    clip_fraction        | 0.152     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.566    |
# |    explained_variance   | 0.962     |
# |    learning_rate        | 0.0001    |
# |    loss                 | 15.2      |
# |    n_updates            | 12180     |
# |    policy_gradient_loss | -0.00711  |
# |    value_loss           | 81.6      |
# ---------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 30          |
# |    time_elapsed         | 1913        |
# |    total_timesteps      | 2503164     |
# | train/                  |             |
# |    approx_kl            | 0.024360636 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.519      |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 10.1        |
# |    n_updates            | 12190       |
# |    policy_gradient_loss | -0.00519    |
# |    value_loss           | 50.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 31          |
# |    time_elapsed         | 2012        |
# |    total_timesteps      | 2505212     |
# | train/                  |             |
# |    approx_kl            | 0.032489795 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.614      |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 87.7        |
# |    n_updates            | 12200       |
# |    policy_gradient_loss | -0.00442    |
# |    value_loss           | 168         |
# -----------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 32          |
# |    time_elapsed         | 2096        |
# |    total_timesteps      | 2507260     |
# | train/                  |             |
# |    approx_kl            | 0.044776034 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.607      |
# |    explained_variance   | 0.922       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 47.5        |
# |    n_updates            | 12210       |
# |    policy_gradient_loss | 0.0024      |
# |    value_loss           | 98          |
# -----------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 31         |
# |    iterations           | 33         |
# |    time_elapsed         | 2175       |
# |    total_timesteps      | 2509308    |
# | train/                  |            |
# |    approx_kl            | 0.03214342 |
# |    clip_fraction        | 0.233      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.594     |
# |    explained_variance   | 0.951      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 24.5       |
# |    n_updates            | 12220      |
# |    policy_gradient_loss | 0.0052     |
# |    value_loss           | 61.3       |
# ----------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 34          |
# |    time_elapsed         | 2271        |
# |    total_timesteps      | 2511356     |
# | train/                  |             |
# |    approx_kl            | 0.025592387 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.59       |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 40.4        |
# |    n_updates            | 12230       |
# |    policy_gradient_loss | -0.0071     |
# |    value_loss           | 83.1        |
# -----------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 35          |
# |    time_elapsed         | 2362        |
# |    total_timesteps      | 2513404     |
# | train/                  |             |
# |    approx_kl            | 0.024657968 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.57       |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 46.2        |
# |    n_updates            | 12240       |
# |    policy_gradient_loss | -0.00499    |
# |    value_loss           | 117         |
# -----------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 29         |
# |    iterations           | 36         |
# |    time_elapsed         | 2458       |
# |    total_timesteps      | 2515452    |
# | train/                  |            |
# |    approx_kl            | 0.02805607 |
# |    clip_fraction        | 0.185      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.581     |
# |    explained_variance   | 0.944      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 28.4       |
# |    n_updates            | 12250      |
# |    policy_gradient_loss | -0.00875   |
# |    value_loss           | 90.2       |
# ----------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 37          |
# |    time_elapsed         | 2561        |
# |    total_timesteps      | 2517500     |
# | train/                  |             |
# |    approx_kl            | 0.029071063 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.642      |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 17.2        |
# |    n_updates            | 12260       |
# |    policy_gradient_loss | -0.00255    |
# |    value_loss           | 49.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 38          |
# |    time_elapsed         | 2655        |
# |    total_timesteps      | 2519548     |
# | train/                  |             |
# |    approx_kl            | 0.023509815 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.608      |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 31.6        |
# |    n_updates            | 12270       |
# |    policy_gradient_loss | -0.00676    |
# |    value_loss           | 97.7        |
# -----------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 39          |
# |    time_elapsed         | 2753        |
# |    total_timesteps      | 2521596     |
# | train/                  |             |
# |    approx_kl            | 0.029656311 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.619      |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 27.8        |
# |    n_updates            | 12280       |
# |    policy_gradient_loss | -0.00342    |
# |    value_loss           | 91.4        |
# -----------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 40          |
# |    time_elapsed         | 2851        |
# |    total_timesteps      | 2523644     |
# | train/                  |             |
# |    approx_kl            | 0.024773225 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.681      |
# |    explained_variance   | 0.947       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 42.8        |
# |    n_updates            | 12290       |
# |    policy_gradient_loss | -0.00581    |
# |    value_loss           | 113         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 41          |
# |    time_elapsed         | 2947        |
# |    total_timesteps      | 2525692     |
# | train/                  |             |
# |    approx_kl            | 0.034880776 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.661      |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 11.6        |
# |    n_updates            | 12300       |
# |    policy_gradient_loss | -0.0038     |
# |    value_loss           | 35          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 42          |
# |    time_elapsed         | 3065        |
# |    total_timesteps      | 2527740     |
# | train/                  |             |
# |    approx_kl            | 0.021255769 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.737      |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 22.3        |
# |    n_updates            | 12310       |
# |    policy_gradient_loss | -3.69e-05   |
# |    value_loss           | 55.8        |
# -----------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 43          |
# |    time_elapsed         | 3169        |
# |    total_timesteps      | 2529788     |
# | train/                  |             |
# |    approx_kl            | 0.028046682 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.691      |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 38.5        |
# |    n_updates            | 12320       |
# |    policy_gradient_loss | -0.00499    |
# |    value_loss           | 78.3        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 27         |
# |    iterations           | 44         |
# |    time_elapsed         | 3243       |
# |    total_timesteps      | 2531836    |
# | train/                  |            |
# |    approx_kl            | 0.03546303 |
# |    clip_fraction        | 0.2        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.712     |
# |    explained_variance   | 0.95       |
# |    learning_rate        | 0.0001     |
# |    loss                 | 28.8       |
# |    n_updates            | 12330      |
# |    policy_gradient_loss | -0.00599   |
# |    value_loss           | 62.1       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 27         |
# |    iterations           | 45         |
# |    time_elapsed         | 3312       |
# |    total_timesteps      | 2533884    |
# | train/                  |            |
# |    approx_kl            | 0.03079203 |
# |    clip_fraction        | 0.188      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.652     |
# |    explained_variance   | 0.928      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 34         |
# |    n_updates            | 12340      |
# |    policy_gradient_loss | -0.00448   |
# |    value_loss           | 119        |
# ----------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 46          |
# |    time_elapsed         | 3386        |
# |    total_timesteps      | 2535932     |
# | train/                  |             |
# |    approx_kl            | 0.034153283 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.639      |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 40.7        |
# |    n_updates            | 12350       |
# |    policy_gradient_loss | 0.000853    |
# |    value_loss           | 115         |
# -----------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 47          |
# |    time_elapsed         | 3459        |
# |    total_timesteps      | 2537980     |
# | train/                  |             |
# |    approx_kl            | 0.039829217 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.674      |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 14.2        |
# |    n_updates            | 12360       |
# |    policy_gradient_loss | -0.00984    |
# |    value_loss           | 48.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 48          |
# |    time_elapsed         | 3533        |
# |    total_timesteps      | 2540028     |
# | train/                  |             |
# |    approx_kl            | 0.027078826 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.645      |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 18.7        |
# |    n_updates            | 12370       |
# |    policy_gradient_loss | -0.00732    |
# |    value_loss           | 54.6        |
# -----------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 49          |
# |    time_elapsed         | 3612        |
# |    total_timesteps      | 2542076     |
# | train/                  |             |
# |    approx_kl            | 0.024191795 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.751      |
# |    explained_variance   | 0.96        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 38.8        |
# |    n_updates            | 12380       |
# |    policy_gradient_loss | -0.00317    |
# |    value_loss           | 85.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 50          |
# |    time_elapsed         | 3683        |
# |    total_timesteps      | 2544124     |
# | train/                  |             |
# |    approx_kl            | 0.029188756 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.726      |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 9.63        |
# |    n_updates            | 12390       |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 32.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 51          |
# |    time_elapsed         | 3781        |
# |    total_timesteps      | 2546172     |
# | train/                  |             |
# |    approx_kl            | 0.023456993 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.569      |
# |    explained_variance   | 0.954       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 37.4        |
# |    n_updates            | 12400       |
# |    policy_gradient_loss | -0.00567    |
# |    value_loss           | 100         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 27         |
# |    iterations           | 52         |
# |    time_elapsed         | 3868       |
# |    total_timesteps      | 2548220    |
# | train/                  |            |
# |    approx_kl            | 0.02774242 |
# |    clip_fraction        | 0.18       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.631     |
# |    explained_variance   | 0.956      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 27.5       |
# |    n_updates            | 12410      |
# |    policy_gradient_loss | -0.00656   |
# |    value_loss           | 118        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 53          |
# |    time_elapsed         | 3948        |
# |    total_timesteps      | 2550268     |
# | train/                  |             |
# |    approx_kl            | 0.023223601 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.619      |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 65.8        |
# |    n_updates            | 12420       |
# |    policy_gradient_loss | -0.0051     |
# |    value_loss           | 128         |
# -----------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 54          |
# |    time_elapsed         | 4044        |
# |    total_timesteps      | 2552316     |
# | train/                  |             |
# |    approx_kl            | 0.025581062 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.613      |
# |    explained_variance   | 0.959       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 21.3        |
# |    n_updates            | 12430       |
# |    policy_gradient_loss | -0.00858    |
# |    value_loss           | 66.4        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 27         |
# |    iterations           | 55         |
# |    time_elapsed         | 4129       |
# |    total_timesteps      | 2554364    |
# | train/                  |            |
# |    approx_kl            | 0.04217104 |
# |    clip_fraction        | 0.184      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.593     |
# |    explained_variance   | 0.949      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 27.2       |
# |    n_updates            | 12440      |
# |    policy_gradient_loss | -0.00792   |
# |    value_loss           | 94         |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 56          |
# |    time_elapsed         | 4196        |
# |    total_timesteps      | 2556412     |
# | train/                  |             |
# |    approx_kl            | 0.025325026 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.598      |
# |    explained_variance   | 0.944       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 34.7        |
# |    n_updates            | 12450       |
# |    policy_gradient_loss | -0.00964    |
# |    value_loss           | 122         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 57          |
# |    time_elapsed         | 4272        |
# |    total_timesteps      | 2558460     |
# | train/                  |             |
# |    approx_kl            | 0.036633134 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.634      |
# |    explained_variance   | 0.896       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 56          |
# |    n_updates            | 12460       |
# |    policy_gradient_loss | 0.0002      |
# |    value_loss           | 161         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 27         |
# |    iterations           | 58         |
# |    time_elapsed         | 4356       |
# |    total_timesteps      | 2560508    |
# | train/                  |            |
# |    approx_kl            | 0.02935098 |
# |    clip_fraction        | 0.188      |
# |    clip_range           | 0.2        |
# ...
# |    entropy_loss         | -0.679     |
# |    explained_variance   | 0.949      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 25.1       |
# |    n_updates            | 14090      |
# |    policy_gradient_loss | -0.013     |
# |    value_loss           | 82.3       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 221         |
# |    time_elapsed         | 16061       |
# |    total_timesteps      | 2894332     |
# | train/                  |             |
# |    approx_kl            | 0.023739528 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.666      |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 17.7        |
# |    n_updates            | 14100       |
# |    policy_gradient_loss | -0.00605    |
# |    value_loss           | 84.3        |
# -----------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 222         |
# |    time_elapsed         | 16129       |
# |    total_timesteps      | 2896380     |
# | train/                  |             |
# |    approx_kl            | 0.026474817 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.614      |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 71.9        |
# |    n_updates            | 14110       |
# |    policy_gradient_loss | 0.00436     |
# |    value_loss           | 137         |
# -----------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 223         |
# |    time_elapsed         | 16200       |
# |    total_timesteps      | 2898428     |
# | train/                  |             |
# |    approx_kl            | 0.037486084 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.733      |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 10.2        |
# |    n_updates            | 14120       |
# |    policy_gradient_loss | -0.0155     |
# |    value_loss           | 36.3        |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 28        |
# |    iterations           | 224       |
# |    time_elapsed         | 16278     |
# |    total_timesteps      | 2900476   |
# | train/                  |           |
# |    approx_kl            | 0.1533705 |
# |    clip_fraction        | 0.296     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.708    |
# |    explained_variance   | 0.923     |
# |    learning_rate        | 0.0001    |
# |    loss                 | 32.3      |
# |    n_updates            | 14130     |
# |    policy_gradient_loss | -0.0279   |
# |    value_loss           | 114       |
# ---------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 225         |
# |    time_elapsed         | 16347       |
# |    total_timesteps      | 2902524     |
# | train/                  |             |
# |    approx_kl            | 0.030462075 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.767      |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 10.7        |
# |    n_updates            | 14140       |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 31.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 226         |
# |    time_elapsed         | 16410       |
# |    total_timesteps      | 2904572     |
# | train/                  |             |
# |    approx_kl            | 0.033323575 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.67       |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 25.9        |
# |    n_updates            | 14150       |
# |    policy_gradient_loss | -0.00461    |
# |    value_loss           | 80.9        |
# -----------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 28         |
# |    iterations           | 227        |
# |    time_elapsed         | 16475      |
# |    total_timesteps      | 2906620    |
# | train/                  |            |
# |    approx_kl            | 0.06016798 |
# |    clip_fraction        | 0.229      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.607     |
# |    explained_variance   | 0.903      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 97.2       |
# |    n_updates            | 14160      |
# |    policy_gradient_loss | -3.13e-05  |
# |    value_loss           | 184        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 28         |
# |    iterations           | 228        |
# |    time_elapsed         | 16543      |
# |    total_timesteps      | 2908668    |
# | train/                  |            |
# |    approx_kl            | 0.03219832 |
# |    clip_fraction        | 0.179      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.58      |
# |    explained_variance   | 0.891      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 144        |
# |    n_updates            | 14170      |
# |    policy_gradient_loss | 0.00314    |
# |    value_loss           | 298        |
# ----------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 28        |
# |    iterations           | 229       |
# |    time_elapsed         | 16610     |
# |    total_timesteps      | 2910716   |
# | train/                  |           |
# |    approx_kl            | 0.0413348 |
# |    clip_fraction        | 0.281     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.779    |
# |    explained_variance   | 0.933     |
# |    learning_rate        | 0.0001    |
# |    loss                 | 23.1      |
# |    n_updates            | 14180     |
# |    policy_gradient_loss | 6.35e-05  |
# |    value_loss           | 76.4      |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 230         |
# |    time_elapsed         | 16680       |
# |    total_timesteps      | 2912764     |
# | train/                  |             |
# |    approx_kl            | 0.040362515 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.623      |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 33.8        |
# |    n_updates            | 14190       |
# |    policy_gradient_loss | -0.0035     |
# |    value_loss           | 102         |
# -----------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 28         |
# |    iterations           | 231        |
# |    time_elapsed         | 16747      |
# |    total_timesteps      | 2914812    |
# | train/                  |            |
# |    approx_kl            | 0.06435749 |
# |    clip_fraction        | 0.294      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.795     |
# |    explained_variance   | 0.957      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 10.6       |
# |    n_updates            | 14200      |
# |    policy_gradient_loss | -0.011     |
# |    value_loss           | 28.8       |
# ----------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 232         |
# |    time_elapsed         | 16821       |
# |    total_timesteps      | 2916860     |
# | train/                  |             |
# |    approx_kl            | 0.043940306 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.595      |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 10.2        |
# |    n_updates            | 14210       |
# |    policy_gradient_loss | -0.00196    |
# |    value_loss           | 60.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 233         |
# |    time_elapsed         | 16885       |
# |    total_timesteps      | 2918908     |
# | train/                  |             |
# |    approx_kl            | 0.027188733 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.63       |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 14.1        |
# |    n_updates            | 14220       |
# |    policy_gradient_loss | -0.00372    |
# |    value_loss           | 48.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 234         |
# |    time_elapsed         | 16958       |
# |    total_timesteps      | 2920956     |
# | train/                  |             |
# |    approx_kl            | 0.027770968 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.569      |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 33.5        |
# |    n_updates            | 14230       |
# |    policy_gradient_loss | -0.00921    |
# |    value_loss           | 75          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 235         |
# |    time_elapsed         | 17025       |
# |    total_timesteps      | 2923004     |
# | train/                  |             |
# |    approx_kl            | 0.026559796 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.633      |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 27.2        |
# |    n_updates            | 14240       |
# |    policy_gradient_loss | -0.00247    |
# |    value_loss           | 99          |
# -----------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 236         |
# |    time_elapsed         | 17094       |
# |    total_timesteps      | 2925052     |
# | train/                  |             |
# |    approx_kl            | 0.028582588 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.625      |
# |    explained_variance   | 0.699       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 226         |
# |    n_updates            | 14250       |
# |    policy_gradient_loss | -0.00282    |
# |    value_loss           | 424         |
# -----------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 28         |
# |    iterations           | 237        |
# |    time_elapsed         | 17165      |
# |    total_timesteps      | 2927100    |
# | train/                  |            |
# |    approx_kl            | 0.02899956 |
# |    clip_fraction        | 0.191      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.632     |
# |    explained_variance   | 0.935      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 50.1       |
# |    n_updates            | 14260      |
# |    policy_gradient_loss | -0.0111    |
# |    value_loss           | 96.9       |
# ----------------------------------------
#
# --- !!! BANDIERA RAGGIUNTA !!! ---
# Salvataggio modello speciale in corso...
# Modello salvato come: ./train/ttlivelli\mario_model_VITTORIA.zip
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 238         |
# |    time_elapsed         | 17239       |
# |    total_timesteps      | 2929148     |
# | train/                  |             |
# |    approx_kl            | 0.031395815 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.524      |
# |    explained_variance   | 0.848       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 123         |
# |    n_updates            | 14270       |
# |    policy_gradient_loss | -0.00127    |
# |    value_loss           | 307         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 239         |
# |    time_elapsed         | 17304       |
# |    total_timesteps      | 2931196     |
# | train/                  |             |
# |    approx_kl            | 0.020105004 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.643      |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 97.5        |
# |    n_updates            | 14280       |
# |    policy_gradient_loss | -0.00229    |
# |    value_loss           | 174         |
# -----------------------------------------
# Salvataggio modello finale...
